# %%
import pandas as pd
import numpy as np

# for handling text
import string
import nltk
import seaborn as sns
# %matplotlib inline
import sklearn
import regex as re
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import time
from termcolor import colored
stop_words = set(stopwords.words('english'))

# for plots
import matplotlib as plty
import matplotlib.pyplot as plt
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.express as px
# %matplotlib inline

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import cross_val_score

pd.set_option('display.max_colwidth', None)
# Out:
# [nltk_data] Downloading package stopwords to /home/konst/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/konst/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from text_class_basic_funcs import *
# Out:
# [nltk_data] Downloading package stopwords to /home/konst/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/konst/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2022-09-10 11:47:37.079673: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-10 11:47:37.180783: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-10 11:47:37.180799: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-09-10 11:47:37.197866: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-10 11:47:37.595826: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-09-10 11:47:37.595895: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-09-10 11:47:37.595901: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
df = pd.read_csv("../data/Sheet_1.csv")
df.dropna(inplace=True, axis=1 )
df.head(4)
# Out:
#   response_id        class  \
# 0  response_1  not_flagged
# 1  response_2      flagged
# 2  response_3      flagged
# 3  response_4  not_flagged
#
#                                                                                                                         response_text
# 0                                                                                               I try and avoid this sort of conflict
# 1          Had a friend open up to me about his mental addiction to weed and how it was taking over his life and making him depressed
# 2  I saved a girl from suicide once. She was going to swallow a bunch of pills and I talked her out of it in a very calm, loving way.
# 3                                                                          i cant think of one really...i think i may have indirectly

# %%
fig = px.histogram(df, x='class', title='distribution of records')
fig.show()
# Out:
# <div>                            <div id="1622820e-e93e-4421-844c-784b09ccb1dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1622820e-e93e-4421-844c-784b09ccb1dc")) {                    Plotly.newPlot(                        "1622820e-e93e-4421-844c-784b09ccb1dc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"class=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["not_flagged","flagged","flagged","not_flagged","not_flagged","not_flagged","flagged","flagged","not_flagged","flagged","not_flagged","flagged","not_flagged","not_flagged","not_flagged","flagged","not_flagged","not_flagged","not_flagged","not_flagged","not_flagged","flagged","flagged","not_flagged","not_flagged","flagged","flagged","not_flagged","flagged","not_flagged","not_flagged","not_flagged","not_flagged","not_flagged","not_flagged","not_flagged","flagged","not_flagged","flagged","not_flagged","flagged","not_flagged","not_flagged","not_flagged","not_flagged","not_flagged","not_flagged","not_flagged","flagged","not_flagged","not_flagged","flagged","not_flagged","not_flagged","not_flagged","not_flagged","not_flagged","flagged","not_flagged","flagged","not_flagged","flagged","not_flagged","not_flagged","flagged","not_flagged","not_flagged","not_flagged","not_flagged","not_flagged","not_flagged","not_flagged","flagged","not_flagged","flagged","not_flagged","flagged","not_flagged","flagged","not_flagged"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"# ...

# %% [markdown]
# ### Clean the data 🚿<a id="clean"></a>

# %%
df = tokenize_text(df)
df = clean(df)
df.loc[:, 'cleaned_text'] = join_tokens(df, 'cleaned_word_list')
display(df.head(1))

df_f = df[df['class'] == 'flagged']
df_n = df[df['class'] == 'not_flagged']
# Out:
#   response_id        class                          response_text  \
# 0  response_1  not_flagged  I try and avoid this sort of conflict
#
#                                         word_list  \
# 0  [I, try, and, avoid, this, sort, of, conflict]
#
#               cleaned_word_list             cleaned_text
# 0  [try, avoid, sort, conflict]  try avoid sort conflict

# %% [markdown]
# ### Create a data frame with count and TFIDF scores for words

# %%
df_f_words_freq = convert_tokens_list_to_freq_df(df_f.cleaned_word_list)
df_n_words_freq = convert_tokens_list_to_freq_df(df_n.cleaned_word_list)

display(df_f_words_freq.head())

tfidf_scores_f = create_tfidf_df(df_f.loc[:, 'cleaned_text'])
tfidf_scores_n = create_tfidf_df(df_n.loc[:, 'cleaned_text'])

f_words_df = merge(df_f_words_freq, tfidf_scores_f)
n_words_df = merge(df_n_words_freq, tfidf_scores_n)

display(f_words_df.head(4))
display(n_words_df.head(4))
# Out:
#      words  freq
# 0   friend    13
# 1   people    10
# 2  friends     9
# 3    would     7
# 4    going     6
#      words  freq  tfidf_score_sum
# 0   friend    13         1.848679
# 1   people    10         0.877912
# 2  friends     9         1.279314
# 3    would     7         0.569055
#      words  freq  tfidf_score_sum
# 0  friends    15         3.921829
# 1   people    10         2.230480
# 2   friend     9         2.241216
# 3   helped     9         2.909667

# %%
# n most frequent
n = 30

fig = px.bar(
    data_frame=f_words_df[:n], x='words', y='freq', color='freq',
    text='tfidf_score_sum', labels={'x': 'words', 'y': 'frequency'},
    title='Frequency of words seen in <b> Flagged </b>records (with TFIDF in parentheses)' )

fig.update_xaxes(tickangle= -45)  
fig.update_traces(
    texttemplate='%{text:.2f}', textposition='outside',
     textfont_size=8)
     
fig.show()
# Out:
# <div>                            <div id="6576358e-fe5a-4661-a33c-fd0c80a2be92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6576358e-fe5a-4661-a33c-fd0c80a2be92")) {                    Plotly.newPlot(                        "6576358e-fe5a-4661-a33c-fd0c80a2be92",                        [{"alignmentgroup":"True","hovertemplate":"words=%{x}<br>freq=%{marker.color}<br>tfidf_score_sum=%{text}<extra></extra>","legendgroup":"","marker":{"color":[13,10,9,7,6,6,6,6,6,5,5,5,5,5,4,4,4,4,4,4,4,3,3,3,3,3,3,3,3,3],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[1.8486788576924351,0.8779124695838775,1.2793135589551663,0.5690545383349216,1.1681508880916947,0.826616755562358,0.8268106795114002,1.3107955553018888,0.6221105722516699,0.8524348184795918,0.6827784489834423,0.7910250223733382,1.0440665847538253,0.797844847803608,0.5371759520991253,0.49056495787469734,0.7859532769138112,0.42632314900335033,0.41426076195249806,0.6442255209492196,0.5430017950030757,0.8503269915410376,0.4732070932087496,0.5164725369733961,0.7044244074975589,0.5754598105934529,0.44815112085209374,0.4301879972424456,0.7670433440907025,0.3332599435933722],"textposition":"outside","x":["friend","people","friends","would","going","get","helped","depression","help","addiction","talk","anxiety","best","school","life","talked","issues","go","back","one","try","suicide","way","could","severe","personal","got","year","tried","everything"],"xaxis":"x","y":[13,10,9,7,6,6,6,6,6,5,5,5,5,5,4,4,4,4,4,4,4,3,3,3,3,3,3,3,3,3],"yaxis":"y","type":"bar","textfont":{"size":8},"texttemplate":"%{text:.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{ ...

# %%
fig = px.bar(
    data_frame=n_words_df[:n], x='words', y='freq', color='freq',
    text='tfidf_score_sum', labels={'x': 'words', 'y': 'frequency'},
    title='Frequency of words seen in <b> Flagged </b>records (with TFIDF in parentheses)')

fig.update_xaxes(tickangle= -45)  
fig.update_traces(
    texttemplate='%{text:.2f}', textposition='outside',
     textfont_size=8)
     
fig.show()
# Out:
# <div>                            <div id="57cba005-218d-4985-90b5-43e572329246" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57cba005-218d-4985-90b5-43e572329246")) {                    Plotly.newPlot(                        "57cba005-218d-4985-90b5-43e572329246",                        [{"alignmentgroup":"True","hovertemplate":"words=%{x}<br>freq=%{marker.color}<br>tfidf_score_sum=%{text}<extra></extra>","legendgroup":"","marker":{"color":[15,10,9,9,8,8,6,6,5,5,5,5,5,5,5,5,5,4,4,4,4,4,4,4,4,3,3,3,3,3],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[3.9218292440998543,2.230480088749043,2.2412155792093458,2.9096669230521757,1.8551567007185192,1.868548107238862,1.5174566111515966,1.263835325919798,1.3534647306548868,1.2631118852824954,1.078936330139842,1.022396546954713,1.0513604618827992,1.627977449061783,1.0677182983557993,1.6248144310837116,1.1905608283560705,1.0184980334701657,0.8774798702428064,1.0585618200538072,1.2599583426509842,1.0186018759866924,1.470431183637305,1.1474790972332682,1.0729006302350315,0.6224650919425996,1.0128993104434838,0.9541012182476344,0.8845609730090858,0.541388018827886],"textposition":"outside","x":["friends","people","friend","helped","talk","help","someone","know","try","think","really","going","feel","always","girl","problems","lot","one","would","open","listen","well","come","life","talked","much","school","shit","advice","week"],"xaxis":"x","y":[15,10,9,9,8,8,6,6,5,5,5,5,5,5,5,5,5,4,4,4,4,4,4,4,4,3,3,3,3,3],"yaxis":"y","type":"bar","textfont":{"size":8},"texttemplate":"%{text:.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks ...

# %%
n_words_df = n_words_df.add_suffix('_n')
n_words_df.rename(columns={'words_n': 'words'}, inplace=True)

f_words_df = f_words_df.add_suffix('_f')
f_words_df.rename(columns={'words_f': 'words'}, inplace=True)

merged_df = merge(f_words_df, n_words_df)
display(merged_df)
# Out:
#           words  freq_f  tfidf_score_sum_f  freq_n  tfidf_score_sum_n
# 0        friend      13           1.848679     9.0           2.241216
# 1        people      10           0.877912    10.0           2.230480
# 2       friends       9           1.279314    15.0           3.921829
# 3         would       7           0.569055     4.0           0.877480
# 4         going       6           1.168151     5.0           1.022397
# ..          ...     ...                ...     ...                ...
# 343       spent       1           0.170482     NaN                NaN
# 344      nights       1           0.170482     NaN                NaN
# 345     letting       1           0.170482     2.0           0.705452
# 346        vent       1           0.170482     NaN                NaN
# 347  supporting       1           0.170482     NaN                NaN
#
# [348 rows x 5 columns]

# %%
merged_df_sample = merged_df[:n]
fig = go.Figure(data=[
    go.Bar(name='Flagged', x=merged_df_sample.words, y=merged_df_sample.freq_f, text=merged_df_sample.freq_f, marker_color='#BA0F30'),
    go.Bar(name='Not Flagged', x=merged_df_sample.words, y=merged_df_sample.freq_n, text=merged_df_sample.freq_n, marker_color='#98D7C2')
])


fig.update_xaxes(tickangle= -45)  
fig.update_traces(
    texttemplate='%{text:d}', textposition='outside',
     textfont_size=8)

# Change the bar mode
fig.update_layout(barmode='group', title_text='most frequent Flagged/not flagged words count comparison')
fig.show()
# Out:
# <div>                            <div id="dbc8ff2b-10fd-4c77-b147-8db7dd3ec916" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbc8ff2b-10fd-4c77-b147-8db7dd3ec916")) {                    Plotly.newPlot(                        "dbc8ff2b-10fd-4c77-b147-8db7dd3ec916",                        [{"marker":{"color":"#BA0F30"},"name":"Flagged","text":[13.0,10.0,9.0,7.0,6.0,6.0,6.0,6.0,6.0,5.0,5.0,5.0,5.0,5.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,3.0,3.0,3.0,3.0,3.0,3.0,3.0,3.0,3.0],"x":["friend","people","friends","would","going","get","helped","depression","help","addiction","talk","anxiety","best","school","life","talked","issues","go","back","one","try","suicide","way","could","severe","personal","got","year","tried","everything"],"y":[13,10,9,7,6,6,6,6,6,5,5,5,5,5,4,4,4,4,4,4,4,3,3,3,3,3,3,3,3,3],"type":"bar","textfont":{"size":8},"textposition":"outside","texttemplate":"%{text:d}"},{"marker":{"color":"#98D7C2"},"name":"Not Flagged","text":[9.0,10.0,15.0,4.0,5.0,2.0,9.0,null,8.0,null,8.0,null,2.0,3.0,4.0,4.0,3.0,2.0,1.0,4.0,5.0,null,2.0,1.0,null,1.0,2.0,null,1.0,null],"x":["friend","people","friends","would","going","get","helped","depression","help","addiction","talk","anxiety","best","school","life","talked","issues","go","back","one","try","suicide","way","could","severe","personal","got","year","tried","everything"],"y":[9.0,10.0,15.0,4.0,5.0,2.0,9.0,null,8.0,null,8.0,null,2.0,3.0,4.0,4.0,3.0,2.0,1.0,4.0,5.0,null,2.0,1.0,null,1.0,2.0,null,1.0,null],"type":"bar","textfont":{"size":8},"textposition":"outside","texttemplate":"%{text:d}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[ ...

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

# %%
transformed_data, words = get_tfidf_words_and_array(df.loc[:, 'cleaned_text'])
y = df.loc[:, 'class']
scores = cross_val_score(nb, transformed_data, y, cv=3)
display(scores)
# Out:
# array([0.44444444, 0.37037037, 0.69230769])

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier()
scores = cross_val_score(random_forest, transformed_data, y, cv=3)
display(scores)
# Out:
# array([0.7037037 , 0.66666667, 0.73076923])

# %% [markdown]
# # Deep Learning <a id="deeplearning"></a>

# %%
import tensorflow as tf
import keras

from tensorflow.keras import layers, callbacks
from sklearn.model_selection import KFold
from keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, LSTM, Dense, SimpleRNN, BatchNormalization

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
text = df.loc[:, 'response_text'].values
pad_type = 'post'
trunc_type='post'

# Tokenize our training data
tokenizer = Tokenizer()
texts = [str (item) for item in df.loc[:, 'response_text']]
tokenizer.fit_on_texts(texts)

# word index = {'word': idx}
word_index = tokenizer.word_index

# Encode into sequences
encoded_seqs = tokenizer.texts_to_sequences(texts)

# %%
padded_lengths = [len(encoded_seqs_i) for encoded_seqs_i in encoded_seqs]
px.histogram(padded_lengths)
# Out:
# <div>                            <div id="b4358a9c-fa7f-4749-98f9-46b76a59839f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4358a9c-fa7f-4749-98f9-46b76a59839f")) {                    Plotly.newPlot(                        "b4358a9c-fa7f-4749-98f9-46b76a59839f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[8,25,29,12,72,25,21,38,13,41,61,22,6,1,4,17,12,5,17,21,4,15,71,37,14,32,23,15,9,32,9,15,22,52,17,49,90,59,59,13,19,44,11,2,24,32,11,20,304,10,20,21,23,8,17,89,20,181,10,50,10,21,6,42,30,4,25,18,30,23,1,14,21,24,34,62,15,16,73,30],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size ...

# %%
max_len = 60
padded_texts = pad_sequences(encoded_seqs, padding=pad_type, truncating=trunc_type, maxlen=max_len)

# %%
# Output the results of our work
random_i = np.random.randint(len(df))

print("Encoded sample:", encoded_seqs[random_i])
print("Padded sample:", padded_texts[random_i])
print("Padded shape:", padded_texts.shape)
print("sequences data type:", type(encoded_seqs))
print("Padded  sequences data type:", type(padded_texts))
# Out:
# Encoded sample: [113, 20, 77, 48, 23, 10, 648, 86, 62, 109, 649, 295, 137, 1, 28, 86, 650, 87, 27, 651, 8, 117, 11, 156, 3, 171, 18, 39, 23, 161, 297, 3, 208, 60, 78, 21, 92, 107, 652, 27, 8, 184, 135, 653, 1, 654, 14, 86, 132, 87, 655, 3, 656, 1, 168, 72, 111, 24, 257, 39, 1, 35]
# Padded sample: [113  20  77  48  23  10 648  86  62 109 649 295 137   1  28  86 650  87
#   27 651   8 117  11 156   3 171  18  39  23 161 297   3 208  60  78  21
#   92 107 652  27   8 184 135 653   1 654  14  86 132  87 655   3 656   1
#  168  72 111  24 257  39]
# Padded shape: (80, 60)
# sequences data type: <class 'list'>
# Padded  sequences data type: <class 'numpy.ndarray'>

# %% [markdown]
# ### Simple RNN

# %%
num_features = len(word_index) + 1

# %%
sample = to_categorical_tensor(padded_texts[0], num_features, max_len)
print(sample.shape)
# Out:
# (60, 678)
# 2022-09-10 11:47:38.954259: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-09-10 11:47:38.954292: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-10 11:47:38.954306: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DESKTOP-ASL3LMV): /proc/driver/nvidia/version does not exist
# 2022-09-10 11:47:38.954549: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# one-hot-encoding
X = [to_categorical_tensor(padded_texts[i], num_features, max_len) for i in range(len(df))]

# converting into an array
X_final = np.reshape(X, (len(X), max_len, num_features))

# %%
labels = np.array([1 if label=='flagged' else 0 for label in df.loc[:, 'class']])

# %%
def create_simpleRNN(rnn_nodes=32):

    model = Sequential([
        SimpleRNN(32, input_shape=(max_len, num_features)),
        BatchNormalization(),
        Dense(1, activation="sigmoid")
        ])
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

    return model

model = create_simpleRNN()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 32)                22752
#
#  batch_normalization (BatchN  (None, 32)               128
#  ormalization)
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 22,913
# Trainable params: 22,849
# Non-trainable params: 64
# _________________________________________________________________

# %%
n_epochs = 3
n_splits = 3
batch_s = 16 # the default is 32
mean_val_acc_models = {}

# %%
mean_val_acc_models['SimpleRNN'] = evaluate(X=X_final, Y=labels, 
                                            model_=create_simpleRNN)
print(mean_val_acc_models)
# Out:
# fold 1
# Epoch 1/20
# 2/2 - 1s - loss: 0.6667 - accuracy: 0.6604 - val_loss: 0.6822 - val_accuracy: 0.6667 - 710ms/epoch - 355ms/step
# Epoch 2/20
# 2/2 - 0s - loss: 0.5398 - accuracy: 0.8113 - val_loss: 0.6758 - val_accuracy: 0.6296 - 42ms/epoch - 21ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 0.4812 - accuracy: 0.8679 - val_loss: 0.6715 - val_accuracy: 0.6296 - 35ms/epoch - 17ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 0.4502 - accuracy: 0.8491 - val_loss: 0.6675 - val_accuracy: 0.6296 - 38ms/epoch - 19ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 0.3614 - accuracy: 0.9245 - val_loss: 0.6646 - val_accuracy: 0.6667 - 38ms/epoch - 19ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 0.2997 - accuracy: 0.9434 - val_loss: 0.6659 - val_accuracy: 0.6667 - 33ms/epoch - 17ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 0.2621 - accuracy: 0.9245 - val_loss: 0.6715 - val_accuracy: 0.6667 - 32ms/epoch - 16ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 0.2508 - accuracy: 0.9057 - val_loss: 0.6763 - val_accuracy: 0.5556 - 33ms/epoch - 17ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 0.1712 - accuracy: 0.9623 - val_loss: 0.6765 - val_accuracy: 0.5926 - 33ms/epoch - 16ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 0.1423 - accuracy: 1.0000 - val_loss: 0.6732 - val_accuracy: 0.5926 - 33ms/epoch - 16ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 0.1114 - accuracy: 1.0000 - val_loss: 0.6722 - val_accuracy: 0.5926 - 34ms/epoch - 17ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 0.0957 - accuracy: 1.0000 - val_loss: 0.6724 - val_accuracy: 0.5556 - 34ms/epoch - 17ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 0.0844 - accuracy: 1.0000 - val_loss: 0.6743 - val_accuracy: 0.5556 - 34ms/epoch - 17ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 0.0690 - accuracy: 1.0000 - val_loss: 0.6795 - val_accuracy: 0.5556 - 34ms/epoch - 17ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.6852 - val_accuracy: 0.5926 - 37ms/epoch - 19ms/step
#
# fold 2
# Epoch 1/20
# 2/2 - 1s - loss: 1.1781 - accuracy: 0.3585 - val_loss: 0.7850 - val_accuracy: 0.1481 - 644ms/epoch - 322ms/step
# Epoch 2/20
# 2/2 - 0s - loss: 0.5959 - accuracy: 0.6981 - val_loss: 0.6652 - val_accuracy: 0.6667 - 36ms/epoch - 18ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 0.5011 - accuracy: 0.8113 - val_loss: 0.6394 - val_accuracy: 0.7407 - 36ms/epoch - 18ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 0.4206 - accuracy: 0.8491 - val_loss: 0.6531 - val_accuracy: 0.7037 - 34ms/epoch - 17ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 0.3116 - accuracy: 0.9434 - val_loss: 0.6828 - val_accuracy: 0.5556 - 33ms/epoch - 17ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 0.2440 - accuracy: 0.9623 - val_loss: 0.7062 - val_accuracy: 0.4444 - 32ms/epoch - 16ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 0.2188 - accuracy: 0.9434 - val_loss: 0.7000 - val_accuracy: 0.4815 - 33ms/epoch - 16ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 0.1702 - accuracy: 0.9434 - val_loss: 0.6716 - val_accuracy: 0.5556 - 32ms/epoch - 16ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 0.1190 - accuracy: 1.0000 - val_loss: 0.6365 - val_accuracy: 0.5926 - 33ms/epoch - 17ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 0.0874 - accuracy: 1.0000 - val_loss: 0.6180 - val_accuracy: 0.6667 - 33ms/epoch - 16ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 0.0681 - accuracy: 1.0000 - val_loss: 0.6210 - val_accuracy: 0.6296 - 33ms/epoch - 17ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 0.0565 - accuracy: 1.0000 - val_loss: 0.6458 - val_accuracy: 0.5926 - 33ms/epoch - 16ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 0.0556 - accuracy: 1.0000 - val_loss: 0.6731 - val_accuracy: 0.5185 - 33ms/epoch - 17ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 0.0715 - accuracy: 1.0000 - val_loss: 0.6820 - val_accuracy: 0.5185 - 32ms/epoch - 16ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.6496 - val_accuracy: 0.5926 - 32ms/epoch - 16ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.6258 - val_accuracy: 0.6296 - 33ms/epoch - 17ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.6114 - val_accuracy: 0.6296 - 32ms/epoch - 16ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.6052 - val_accuracy: 0.6296 - 35ms/epoch - 17ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.6056 - val_accuracy: 0.6296 - 32ms/epoch - 16ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.6171 - val_accuracy: 0.6296 - 32ms/epoch - 16ms/step
#
# fold 3
# Epoch 1/20
# 2/2 - 1s - loss: 0.6703 - accuracy: 0.6111 - val_loss: 0.6235 - val_accuracy: 0.6538 - 644ms/epoch - 322ms/step
# Epoch 2/20
# 2/2 - 0s - loss: 0.5211 - accuracy: 0.8519 - val_loss: 0.6237 - val_accuracy: 0.6538 - 35ms/epoch - 18ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 0.4333 - accuracy: 0.9259 - val_loss: 0.6271 - val_accuracy: 0.6538 - 36ms/epoch - 18ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 0.3753 - accuracy: 0.9074 - val_loss: 0.6329 - val_accuracy: 0.6538 - 34ms/epoch - 17ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 0.3040 - accuracy: 0.9259 - val_loss: 0.6399 - val_accuracy: 0.6538 - 34ms/epoch - 17ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 0.2722 - accuracy: 0.9259 - val_loss: 0.6429 - val_accuracy: 0.6923 - 34ms/epoch - 17ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 0.2544 - accuracy: 0.9444 - val_loss: 0.6419 - val_accuracy: 0.6923 - 37ms/epoch - 18ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 0.1867 - accuracy: 0.9630 - val_loss: 0.6330 - val_accuracy: 0.6538 - 36ms/epoch - 18ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 0.1429 - accuracy: 0.9815 - val_loss: 0.6269 - val_accuracy: 0.6923 - 35ms/epoch - 17ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 0.1301 - accuracy: 0.9815 - val_loss: 0.6295 - val_accuracy: 0.6538 - 36ms/epoch - 18ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 0.1114 - accuracy: 1.0000 - val_loss: 0.6373 - val_accuracy: 0.6538 - 36ms/epoch - 18ms/step
# {'SimpleRNN': [0.60987655321757, 0.5777777761220932, 0.6643356626684015]}

# %% [markdown]
# ### GRU

# %%
def create_GRU(embedding_dim=32, gru_d=32):

    model = Sequential([
        Embedding(input_dim=num_features, output_dim=embedding_dim, input_length=max_len),
        GRU(gru_d),
        BatchNormalization(),
        Dense(1, activation="sigmoid")
        ])
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

    return model

model = create_GRU()
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 60, 32)            21696
#
#  gru (GRU)                   (None, 32)                6336
#
#  batch_normalization_4 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 28,193
# Trainable params: 28,129
# Non-trainable params: 64
# _________________________________________________________________

# %%
mean_val_acc_models['GRU'] = evaluate(X=padded_texts, Y=labels, model_=create_GRU)
# Out:
# fold 1
# Epoch 1/20
# 2/2 - 1s - loss: 0.6681 - accuracy: 0.7736 - val_loss: 0.6882 - val_accuracy: 0.6296 - 1s/epoch - 666ms/step
# Epoch 2/20
# 2/2 - 0s - loss: 0.6296 - accuracy: 0.7736 - val_loss: 0.6863 - val_accuracy: 0.5926 - 51ms/epoch - 26ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 0.6114 - accuracy: 0.7736 - val_loss: 0.6846 - val_accuracy: 0.5926 - 46ms/epoch - 23ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 0.5865 - accuracy: 0.7736 - val_loss: 0.6836 - val_accuracy: 0.5926 - 45ms/epoch - 22ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 0.5650 - accuracy: 0.7736 - val_loss: 0.6826 - val_accuracy: 0.5926 - 45ms/epoch - 23ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 0.5558 - accuracy: 0.7736 - val_loss: 0.6818 - val_accuracy: 0.5926 - 47ms/epoch - 23ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 0.5442 - accuracy: 0.7736 - val_loss: 0.6814 - val_accuracy: 0.5926 - 45ms/epoch - 23ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 0.5235 - accuracy: 0.7736 - val_loss: 0.6809 - val_accuracy: 0.5926 - 46ms/epoch - 23ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 0.5044 - accuracy: 0.8302 - val_loss: 0.6805 - val_accuracy: 0.5926 - 47ms/epoch - 23ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 0.5031 - accuracy: 0.8302 - val_loss: 0.6800 - val_accuracy: 0.5926 - 45ms/epoch - 23ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 0.4999 - accuracy: 0.8302 - val_loss: 0.6796 - val_accuracy: 0.5926 - 46ms/epoch - 23ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 0.4687 - accuracy: 0.8302 - val_loss: 0.6793 - val_accuracy: 0.5926 - 48ms/epoch - 24ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 0.5109 - accuracy: 0.8302 - val_loss: 0.6790 - val_accuracy: 0.5926 - 47ms/epoch - 23ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 0.4633 - accuracy: 0.8302 - val_loss: 0.6788 - val_accuracy: 0.5926 - 45ms/epoch - 23ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 0.4705 - accuracy: 0.8302 - val_loss: 0.6788 - val_accuracy: 0.5926 - 45ms/epoch - 22ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 0.4375 - accuracy: 0.8302 - val_loss: 0.6789 - val_accuracy: 0.5926 - 45ms/epoch - 23ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 0.4362 - accuracy: 0.8302 - val_loss: 0.6793 - val_accuracy: 0.5926 - 45ms/epoch - 22ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 0.4419 - accuracy: 0.8302 - val_loss: 0.6798 - val_accuracy: 0.5926 - 45ms/epoch - 22ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 0.4212 - accuracy: 0.8302 - val_loss: 0.6804 - val_accuracy: 0.5926 - 45ms/epoch - 23ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 0.4672 - accuracy: 0.8302 - val_loss: 0.6808 - val_accuracy: 0.5926 - 45ms/epoch - 23ms/step
#
# fold 2
# Epoch 1/20
# 2/2 - 2s - loss: 0.7254 - accuracy: 0.5849 - val_loss: 0.6801 - val_accuracy: 0.7778 - 2s/epoch - 770ms/step
# Epoch 2/20
# 2/2 - 0s - loss: 0.6993 - accuracy: 0.6226 - val_loss: 0.6772 - val_accuracy: 0.7778 - 51ms/epoch - 26ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 0.6815 - accuracy: 0.6415 - val_loss: 0.6726 - val_accuracy: 0.7778 - 48ms/epoch - 24ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 0.6622 - accuracy: 0.6415 - val_loss: 0.6690 - val_accuracy: 0.7778 - 47ms/epoch - 23ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 0.6530 - accuracy: 0.6604 - val_loss: 0.6653 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 0.6388 - accuracy: 0.6981 - val_loss: 0.6615 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 0.6275 - accuracy: 0.6981 - val_loss: 0.6575 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 0.6140 - accuracy: 0.6981 - val_loss: 0.6521 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 0.6083 - accuracy: 0.6981 - val_loss: 0.6463 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 0.6115 - accuracy: 0.5472 - val_loss: 0.6405 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 0.5923 - accuracy: 0.6981 - val_loss: 0.6346 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 0.5878 - accuracy: 0.6981 - val_loss: 0.6288 - val_accuracy: 0.7778 - 47ms/epoch - 23ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 0.5984 - accuracy: 0.5849 - val_loss: 0.6233 - val_accuracy: 0.7778 - 48ms/epoch - 24ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 0.5831 - accuracy: 0.6981 - val_loss: 0.6184 - val_accuracy: 0.7778 - 50ms/epoch - 25ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 0.5782 - accuracy: 0.6981 - val_loss: 0.6141 - val_accuracy: 0.7778 - 50ms/epoch - 25ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 0.5732 - accuracy: 0.6981 - val_loss: 0.6099 - val_accuracy: 0.7778 - 48ms/epoch - 24ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 0.6162 - accuracy: 0.6981 - val_loss: 0.6070 - val_accuracy: 0.7778 - 45ms/epoch - 23ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 0.6092 - accuracy: 0.5472 - val_loss: 0.6061 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 0.6021 - accuracy: 0.6981 - val_loss: 0.6049 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 0.5764 - accuracy: 0.6226 - val_loss: 0.6028 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
#
# fold 3
# Epoch 1/20
# 2/2 - 1s - loss: 0.6773 - accuracy: 0.7037 - val_loss: 0.6812 - val_accuracy: 0.7308 - 1s/epoch - 641ms/step
# Epoch 2/20
# 2/2 - 0s - loss: 0.6566 - accuracy: 0.7037 - val_loss: 0.6761 - val_accuracy: 0.7308 - 53ms/epoch - 27ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 0.6415 - accuracy: 0.7037 - val_loss: 0.6727 - val_accuracy: 0.6923 - 47ms/epoch - 23ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 0.6081 - accuracy: 0.7037 - val_loss: 0.6702 - val_accuracy: 0.6923 - 46ms/epoch - 23ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 0.6165 - accuracy: 0.7037 - val_loss: 0.6684 - val_accuracy: 0.6923 - 46ms/epoch - 23ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 0.6047 - accuracy: 0.7407 - val_loss: 0.6669 - val_accuracy: 0.6923 - 45ms/epoch - 23ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 0.5874 - accuracy: 0.7593 - val_loss: 0.6649 - val_accuracy: 0.6923 - 46ms/epoch - 23ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 0.5812 - accuracy: 0.7593 - val_loss: 0.6627 - val_accuracy: 0.6923 - 46ms/epoch - 23ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 0.5750 - accuracy: 0.7593 - val_loss: 0.6600 - val_accuracy: 0.6923 - 45ms/epoch - 22ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 0.5671 - accuracy: 0.7593 - val_loss: 0.6568 - val_accuracy: 0.6923 - 46ms/epoch - 23ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 0.5608 - accuracy: 0.7593 - val_loss: 0.6536 - val_accuracy: 0.6923 - 46ms/epoch - 23ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 0.5592 - accuracy: 0.7593 - val_loss: 0.6512 - val_accuracy: 0.6923 - 47ms/epoch - 23ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 0.5290 - accuracy: 0.7593 - val_loss: 0.6486 - val_accuracy: 0.6923 - 46ms/epoch - 23ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 0.5432 - accuracy: 0.7593 - val_loss: 0.6463 - val_accuracy: 0.6923 - 50ms/epoch - 25ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 0.5469 - accuracy: 0.7593 - val_loss: 0.6440 - val_accuracy: 0.6923 - 48ms/epoch - 24ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 0.5162 - accuracy: 0.7593 - val_loss: 0.6417 - val_accuracy: 0.6923 - 48ms/epoch - 24ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 0.5119 - accuracy: 0.7593 - val_loss: 0.6398 - val_accuracy: 0.6923 - 48ms/epoch - 24ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 0.5096 - accuracy: 0.7593 - val_loss: 0.6377 - val_accuracy: 0.6923 - 47ms/epoch - 23ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 0.5140 - accuracy: 0.7593 - val_loss: 0.6352 - val_accuracy: 0.6923 - 47ms/epoch - 23ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 0.5189 - accuracy: 0.7593 - val_loss: 0.6331 - val_accuracy: 0.6923 - 51ms/epoch - 26ms/step

# %% [markdown]
# ### Long Short-term Memory (LSTM)

# %%
def create_LSTM(embedding_dim=32, lstm_u=32):

    model = Sequential([
        Embedding(input_dim=num_features, output_dim=embedding_dim, input_length=max_len),
        LSTM(lstm_u),
        BatchNormalization(),
        Dense(1, activation="sigmoid")
        ])
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

    return model

model = create_LSTM()
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 60, 32)            21696
#
#  lstm (LSTM)                 (None, 32)                8320
#
#  batch_normalization_8 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 30,177
# Trainable params: 30,113
# Non-trainable params: 64
# _________________________________________________________________

# %%
mean_val_acc_models['LSTM'] = evaluate(X=padded_texts, Y=labels, model_=create_LSTM)
# Out:
# fold 1
# Epoch 1/20
# 2/2 - 1s - loss: 0.7140 - accuracy: 0.4151 - val_loss: 0.6911 - val_accuracy: 0.5926 - 1s/epoch - 631ms/step
# Epoch 2/20
# 2/2 - 0s - loss: 0.6626 - accuracy: 0.7547 - val_loss: 0.6885 - val_accuracy: 0.5926 - 51ms/epoch - 26ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 0.6229 - accuracy: 0.7736 - val_loss: 0.6864 - val_accuracy: 0.5926 - 48ms/epoch - 24ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 0.6105 - accuracy: 0.7736 - val_loss: 0.6847 - val_accuracy: 0.5926 - 47ms/epoch - 23ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 0.5943 - accuracy: 0.7736 - val_loss: 0.6834 - val_accuracy: 0.5926 - 47ms/epoch - 23ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 0.5655 - accuracy: 0.7925 - val_loss: 0.6825 - val_accuracy: 0.5926 - 46ms/epoch - 23ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 0.5594 - accuracy: 0.7736 - val_loss: 0.6819 - val_accuracy: 0.5926 - 49ms/epoch - 25ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 0.5577 - accuracy: 0.7736 - val_loss: 0.6815 - val_accuracy: 0.5926 - 48ms/epoch - 24ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 0.5255 - accuracy: 0.7925 - val_loss: 0.6814 - val_accuracy: 0.5926 - 46ms/epoch - 23ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 0.5137 - accuracy: 0.8113 - val_loss: 0.6816 - val_accuracy: 0.5926 - 45ms/epoch - 22ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 0.4964 - accuracy: 0.8491 - val_loss: 0.6819 - val_accuracy: 0.5926 - 45ms/epoch - 22ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 0.4671 - accuracy: 0.8491 - val_loss: 0.6824 - val_accuracy: 0.5926 - 47ms/epoch - 23ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 0.4460 - accuracy: 0.8491 - val_loss: 0.6831 - val_accuracy: 0.5556 - 55ms/epoch - 28ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 0.5277 - accuracy: 0.6226 - val_loss: 0.6836 - val_accuracy: 0.5556 - 59ms/epoch - 30ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 0.3853 - accuracy: 0.8679 - val_loss: 0.6836 - val_accuracy: 0.5556 - 49ms/epoch - 24ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 0.3851 - accuracy: 0.8491 - val_loss: 0.6847 - val_accuracy: 0.5556 - 48ms/epoch - 24ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 0.2830 - accuracy: 0.9245 - val_loss: 0.6907 - val_accuracy: 0.5926 - 49ms/epoch - 24ms/step
#
# fold 2
# Epoch 1/20
# 2/2 - 2s - loss: 0.6975 - accuracy: 0.6038 - val_loss: 0.6856 - val_accuracy: 0.7778 - 2s/epoch - 776ms/step
# Epoch 2/20
# 2/2 - 0s - loss: 0.6749 - accuracy: 0.6415 - val_loss: 0.6826 - val_accuracy: 0.7778 - 54ms/epoch - 27ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 0.6674 - accuracy: 0.6415 - val_loss: 0.6794 - val_accuracy: 0.7778 - 48ms/epoch - 24ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 0.6499 - accuracy: 0.7170 - val_loss: 0.6734 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 0.6361 - accuracy: 0.7358 - val_loss: 0.6681 - val_accuracy: 0.7778 - 47ms/epoch - 23ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 0.6202 - accuracy: 0.7358 - val_loss: 0.6616 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 0.6070 - accuracy: 0.7358 - val_loss: 0.6553 - val_accuracy: 0.7778 - 45ms/epoch - 23ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 0.5871 - accuracy: 0.7547 - val_loss: 0.6467 - val_accuracy: 0.7778 - 44ms/epoch - 22ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 0.5653 - accuracy: 0.7736 - val_loss: 0.6355 - val_accuracy: 0.7778 - 45ms/epoch - 22ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 0.5333 - accuracy: 0.7358 - val_loss: 0.6204 - val_accuracy: 0.7778 - 44ms/epoch - 22ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 0.4927 - accuracy: 0.7547 - val_loss: 0.6014 - val_accuracy: 0.7778 - 47ms/epoch - 23ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 0.4049 - accuracy: 0.8302 - val_loss: 0.5780 - val_accuracy: 0.7778 - 45ms/epoch - 22ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 0.3044 - accuracy: 0.8868 - val_loss: 0.5510 - val_accuracy: 0.7778 - 44ms/epoch - 22ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 0.2141 - accuracy: 0.9623 - val_loss: 0.5243 - val_accuracy: 0.7778 - 44ms/epoch - 22ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 0.1138 - accuracy: 0.9811 - val_loss: 0.4978 - val_accuracy: 0.7778 - 45ms/epoch - 22ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 0.0440 - accuracy: 0.9811 - val_loss: 0.4922 - val_accuracy: 0.7778 - 47ms/epoch - 24ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.5219 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.5358 - val_accuracy: 0.7778 - 47ms/epoch - 24ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.5290 - val_accuracy: 0.8148 - 46ms/epoch - 23ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5712 - val_accuracy: 0.7778 - 46ms/epoch - 23ms/step
#
# fold 3
# Epoch 1/20
# 2/2 - 1s - loss: 0.6836 - accuracy: 0.6852 - val_loss: 0.6823 - val_accuracy: 0.6923 - 1s/epoch - 625ms/step
# Epoch 2/20
# 2/2 - 0s - loss: 0.6625 - accuracy: 0.6852 - val_loss: 0.6811 - val_accuracy: 0.6923 - 52ms/epoch - 26ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 0.6466 - accuracy: 0.7037 - val_loss: 0.6791 - val_accuracy: 0.6923 - 49ms/epoch - 24ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 0.6320 - accuracy: 0.7037 - val_loss: 0.6773 - val_accuracy: 0.6923 - 48ms/epoch - 24ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 0.6136 - accuracy: 0.7037 - val_loss: 0.6758 - val_accuracy: 0.6923 - 47ms/epoch - 23ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 0.6025 - accuracy: 0.7407 - val_loss: 0.6747 - val_accuracy: 0.6923 - 45ms/epoch - 23ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 0.5923 - accuracy: 0.7593 - val_loss: 0.6738 - val_accuracy: 0.6923 - 45ms/epoch - 22ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 0.5706 - accuracy: 0.7593 - val_loss: 0.6730 - val_accuracy: 0.6923 - 46ms/epoch - 23ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 0.5634 - accuracy: 0.7593 - val_loss: 0.6710 - val_accuracy: 0.6923 - 44ms/epoch - 22ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 0.5440 - accuracy: 0.7593 - val_loss: 0.6689 - val_accuracy: 0.6923 - 47ms/epoch - 23ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 0.5361 - accuracy: 0.7593 - val_loss: 0.6668 - val_accuracy: 0.6923 - 45ms/epoch - 23ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 0.5453 - accuracy: 0.7778 - val_loss: 0.6661 - val_accuracy: 0.6923 - 44ms/epoch - 22ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 0.5111 - accuracy: 0.7778 - val_loss: 0.6682 - val_accuracy: 0.6923 - 45ms/epoch - 23ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 0.4722 - accuracy: 0.7963 - val_loss: 0.6707 - val_accuracy: 0.6923 - 45ms/epoch - 22ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 0.4547 - accuracy: 0.7963 - val_loss: 0.6789 - val_accuracy: 0.7308 - 45ms/epoch - 23ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 0.4013 - accuracy: 0.7963 - val_loss: 0.7038 - val_accuracy: 0.3077 - 45ms/epoch - 22ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 0.3615 - accuracy: 0.8333 - val_loss: 0.7552 - val_accuracy: 0.3077 - 44ms/epoch - 22ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 0.2638 - accuracy: 0.9074 - val_loss: 0.8026 - val_accuracy: 0.3077 - 44ms/epoch - 22ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 0.1697 - accuracy: 0.9630 - val_loss: 0.7926 - val_accuracy: 0.3077 - 44ms/epoch - 22ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 0.1043 - accuracy: 0.9815 - val_loss: 0.8432 - val_accuracy: 0.3077 - 46ms/epoch - 23ms/step

# %%
display(mean_val_acc_models)
# Out:
# {'SimpleRNN': [0.60987655321757, 0.5777777761220932, 0.6643356626684015],
#  'GRU': [0.5944444477558136, 0.7777777910232544, 0.6961538612842559],
#  'LSTM': [0.5838780052521649, 0.7796296417713166, 0.5980769380927086]}
